# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
matplotlib.rcParams['pdf.fonttype'] = 42

# %%
mat = pd.read_csv('motif_similarity_matrix.csv', index_col=0)

# %%
os.makedirs('../figures/Supp/', exist_ok=True)

# %%
fig, ax = plt.subplots(1)
sns.heatmap(mat, vmin=0, cmap='Blues', annot=True, ax=ax)
fig.savefig('../figures/Supp/sr_identity.pdf')
